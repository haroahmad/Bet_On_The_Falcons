# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Combine 3 datasets

# %%
# load the Data Set 1
data_1=pd.read_csv(r"C:\Users\letwu\Documents\005 - Analytics Challenge\NFL Analytics Challenge Data Set 1.csv")

# %%
# Convert data set 1 to a dataframe
data_1_df=pd.DataFrame(data_1)

# %%
data_1_df.head()
# Out:
#        date        away     home  first_downs_away  first_downs_home  \
# 0  9/5/2002    .  49ers   Giants                13                21
# 1  9/8/2002    Seahawks  Raiders                14                27
# 2  9/8/2002        Jets    Bills                18                26
# 3  9/8/2002     Vikings    Bears                19                20
# 4  9/8/2002    Chargers  Bengals                27                13
#
#   third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0             4-12             9-16               0-0               0-1
# 1             1-11             7-12               2-2               1-1
# 2              2-8             7-17               0-0               2-2
# 3             5-13             7-13               0-0               0-0
# 4             6-10             4-11               0-0               0-0
#
#    passing_yards_away  ...  penalties_away  penalties_home  redzone_away  \
# ...

# %%
data_1_df.info()
# no empty value, probably need to conver the date to date, time to time, and split some columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1575 non-null   object
#  1   away                   1575 non-null   object
#  2   home                   1575 non-null   object
#  3   first_downs_away       1575 non-null   int64
#  4   first_downs_home       1575 non-null   int64
#  5   third_downs_away       1575 non-null   object
#  6   third_downs_home       1575 non-null   object
#  7   fourth_downs_away      1575 non-null   object
#  8   fourth_downs_home      1575 non-null   object
#  9   passing_yards_away     1575 non-null   int64
#  10  passing_yards_home     1575 non-null   int64
#  11  rushing_yards_away     1575 non-null   int64
#  12  rushing_yards_home     1575 non-null   int64
#  13  total_yards_away       1575 non-null   int64
# ...

# %%
# load data set 2
data_2=pd.read_csv(r"C:\Users\letwu\Documents\005 - Analytics Challenge\NFL Analytics Challenge Data Set 2.csv")

# %%
# convert data set 2 to a dataframe
data_2_df=pd.DataFrame(data_2)

# %%
data_2_df.head()
# Out:
#         date      away      home  first_downs_away  first_downs_home  \
# 0   1/4/2003     Colts      Jets                10                26
# 1   1/4/2003   Falcons   Packers                21                17
# 2   1/5/2003    Browns  Steelers                21                30
# 3   1/5/2003    Giants     49ers                26                23
# 4  1/11/2003  Steelers    Titans                21                29
#
#   third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0             5-13             6-11               0-0               0-0
# 1             8-17             8-15               0-0               0-3
# 2             8-17             3-10               0-0               0-0
# 3             6-13             6-13               0-0               1-2
# 4             4-14            12-18               0-0               1-1
#
#    passing_yards_away  ...  penalties_away  penalties_home  redzone_away  \
# ...

# %%
data_2_df.info()
# no empty value, probably need to conver the date to date, time to time, and split some columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3513 entries, 0 to 3512
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   3513 non-null   object
#  1   away                   3513 non-null   object
#  2   home                   3513 non-null   object
#  3   first_downs_away       3513 non-null   int64
#  4   first_downs_home       3513 non-null   int64
#  5   third_downs_away       3513 non-null   object
#  6   third_downs_home       3513 non-null   object
#  7   fourth_downs_away      3513 non-null   object
#  8   fourth_downs_home      3513 non-null   object
#  9   passing_yards_away     3513 non-null   int64
#  10  passing_yards_home     3513 non-null   int64
#  11  rushing_yards_away     3513 non-null   int64
#  12  rushing_yards_home     3513 non-null   int64
#  13  total_yards_away       3513 non-null   object
# ...

# %%
# it's werid that total_yards_away is object
data_2_df['total_yards_away'].unique()
# Out:
# array(['176', '309', '447', '446', '324', '354', '228', '287', '308',
#        '312', '269', '158', '232', '280', '239', '293', '271', '434',
#        '337', '393', '355', '231', '331', '318', '127', '359', '328',
#        '435', '236', '380', '390', '258', '376', '371', '175', '323',
#        '416', '382', '208', '403', '316', '414', '188', '266', '329',
#        '426', '311', '399', '249', '251', '118', '195', '335', '295',
#        '161', '372', '198', '387', '342', '430', '265', '285', '360',
#        '267', '418', '279', '301', '151', '343', '468', '411', '344',
#        '346', '307', '305', '455', '254', '482', '458', '341', '379',
#        '234', '215', '193', '261', '209', '332', '506', '401', '289',
#        '321', '134', '348', '300', '169', '326', '211', '319', '203',
#        '260', '459', '450', '368', '448', '178', '320', '194', '255',
#        '270', '377', '264', '213', '199', '356', '413', '257', '367',
# ...

# %%
# need to take ___out
data_2_df.total_yards_away=data_2_df.total_yards_away.str.replace('_','')

# %%
# convert the column from object to integer
data_2_df['total_yards_away']=pd.to_numeric(data_2_df['total_yards_away'])

# %%
data_2_df['total_yards_away'].dtype
# Out:
# dtype('int64')

# %%
data_2_df['total_yards_away'].unique()
# Out:
# array([176, 309, 447, 446, 324, 354, 228, 287, 308, 312, 269, 158, 232,
#        280, 239, 293, 271, 434, 337, 393, 355, 231, 331, 318, 127, 359,
#        328, 435, 236, 380, 390, 258, 376, 371, 175, 323, 416, 382, 208,
#        403, 316, 414, 188, 266, 329, 426, 311, 399, 249, 251, 118, 195,
#        335, 295, 161, 372, 198, 387, 342, 430, 265, 285, 360, 267, 418,
#        279, 301, 151, 343, 468, 411, 344, 346, 307, 305, 455, 254, 482,
#        458, 341, 379, 234, 215, 193, 261, 209, 332, 506, 401, 289, 321,
#        134, 348, 300, 169, 326, 211, 319, 203, 260, 459, 450, 368, 448,
#        178, 320, 194, 255, 270, 377, 264, 213, 199, 356, 413, 257, 367,
#        263, 340, 451, 419, 224, 274, 347, 394, 460, 185, 424, 282, 223,
#        181, 245, 187, 244, 361,  96, 467, 357, 291, 349, 192, 168, 241,
#        330, 466, 472, 217, 415, 444, 277, 212, 365, 197, 465, 283, 243,
#        310, 214, 221, 275, 225, 375, 314, 288, 124, 268, 210, 502, 154,
# ...

# %%
# load the Data Set 3
data_3=pd.read_csv(r"C:\Users\letwu\Documents\005 - Analytics Challenge\NFL Analytics Challenge Data Set 3.csv")

# %%
# convert data set 2 to a dataframe
data_3_df=pd.DataFrame(data_3)

# %%
data_3_df.head()
# Out:
#        date        away     home  score_away  score_home
# 0  9/5/2002    .  49ers   Giants          16          13
# 1  9/8/2002    Seahawks  Raiders          17          31
# 2  9/8/2002        Jets    Bills          37          31
# 3  9/8/2002     Vikings    Bears          23          27
# 4  9/8/2002    Chargers  Bengals          34           6

# %%
data_3_df.columns
# Out:
# Index(['date', 'away', 'home', 'score_away', 'score_home'], dtype='object')

# %%
data_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5088 entries, 0 to 5087
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        5088 non-null   object
#  1   away        5088 non-null   object
#  2   home        5088 non-null   object
#  3   score_away  5088 non-null   int64
#  4   score_home  5088 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 198.9+ KB

# %%
# total rows of data set 1 and 2 equals the total rows of data set 3
len(data_1_df)+len(data_2_df)
# Out:
# 5088

# %%
data_1_df[500:505]
# make sure the #_# format got fixed
# Out:
#            date       away     home  first_downs_away  first_downs_home  \
# 500  12/18/2005   Steelers  Vikings                14                11
# 501  12/18/2005   Panthers   Saints                19                15
# 502  12/18/2005      49ers  Jaguars                11                21
# 503  12/18/2005  Cardinals   Texans                16                18
# 504  12/18/2005    Bengals    Lions                29                13
#
#     third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 500             5-15             3-12               1-1               0-0
# 501             8-17             4-12               0-0               0-1
# 502             1-13             6-17               0-1               0-1
# 503             4-13             5-15               0-0               0-1
# 504            10-14              5-9               0-0               0-0
#
#      passing_yards_away  ...  penalties_away  penalties_home  redzone_away  \
# ...

# %%
# concatenate df 1 and df 2
data_1n2_df=pd.concat([data_1_df,data_2_df])

# %%
data_1n2_df[250:270]
# the concatenate didn't sort the data, both data are in their origial order.Need to sort it later by date
# Out:
#            date          away        home  first_downs_away  first_downs_home  \
# 250  12/29/2002       Jaguars       Colts                20                18
# 251  12/29/2002     Cardinals     Broncos                18                24
# 252  12/29/2002       Packers        Jets                19                22
# 253  12/29/2002      Seahawks    Chargers                34                24
# 254  12/29/2002    Buccaneers       Bears                15                14
# 255  12/30/2002         49ers        Rams                19                16
# 256    1/2/2005    .  Jaguars     Raiders                13                16
# 257    1/2/2005      Steelers       Bills                15                16
# 258    1/2/2005       Packers       Bears                17                17
# 259    1/2/2005         Lions      Titans                23                15
# 260    1/2/2005          Jets        Rams                22                21
# ...

# %%
data_2_df.tail()
# Out:
#            date     away        home  first_downs_away  first_downs_home  \
# 3508  1/23/2022     Rams  Buccaneers                24                20
# 3509  1/23/2022    Bills      Chiefs                23                30
# 3510  1/30/2022  Bengals      Chiefs                21                24
# 3511  1/30/2022    49ers        Rams                16                25
# 3512  2/13/2022     Rams     Bengals                18                15
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 3508             4-11             3-14               0-0               2-4
# 3509             6-14             8-13               4-4               1-1
# 3510             8-14             6-12               0-0               0-0
# 3511              3-9            11-18               0-0               0-1
# 3512             6-15             3-14               1-1               1-3
#
# ...

# %%
data_1n2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5088 entries, 0 to 3512
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   5088 non-null   object
#  1   away                   5088 non-null   object
#  2   home                   5088 non-null   object
#  3   first_downs_away       5088 non-null   int64
#  4   first_downs_home       5088 non-null   int64
#  5   third_downs_away       5088 non-null   object
#  6   third_downs_home       5088 non-null   object
#  7   fourth_downs_away      5088 non-null   object
#  8   fourth_downs_home      5088 non-null   object
#  9   passing_yards_away     5088 non-null   int64
#  10  passing_yards_home     5088 non-null   int64
#  11  rushing_yards_away     5088 non-null   int64
#  12  rushing_yards_home     5088 non-null   int64
#  13  total_yards_away       5088 non-null   int64
# ...

# %%
data_1n2_df.describe()
# Out:
#        first_downs_away  first_downs_home  passing_yards_away  \
# count       5088.000000       5088.000000         5088.000000
# mean          18.970322         19.891313          221.358687
# std            5.081458          4.982906           79.142200
# min            3.000000          3.000000           -7.000000
# 25%           15.000000         16.000000          165.000000
# 50%           19.000000         20.000000          218.000000
# 75%           22.000000         23.000000          275.000000
# max           37.000000         40.000000          516.000000
#
#        passing_yards_home  rushing_yards_away  rushing_yards_home  \
# count         5088.000000         5088.000000         5088.000000
# mean           227.207154          110.201061          117.893868
# std             77.995743           50.639103           52.259083
# min              6.000000          -18.000000           -3.000000
# 25%            173.000000           74.000000           81.000000
# ...

# %%
# join data 1n2 to data 3
data_all_df=pd.merge(data_1n2_df,data_3_df,on=['date', 'away', 'home'])

# %%
data_all_df.head()
# Out:
#        date        away     home  first_downs_away  first_downs_home  \
# 0  9/5/2002    .  49ers   Giants                13                21
# 1  9/8/2002    Seahawks  Raiders                14                27
# 2  9/8/2002        Jets    Bills                18                26
# 3  9/8/2002     Vikings    Bears                19                20
# 4  9/8/2002    Chargers  Bengals                27                13
#
#   third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0             4-12             9-16               0-0               0-1
# 1             1-11             7-12               2-2               1-1
# 2              2-8             7-17               0-0               2-2
# 3             5-13             7-13               0-0               0-0
# 4             6-10             4-11               0-0               0-0
#
#    passing_yards_away  ...  redzone_away  redzone_home  drives_away  \
# ...

# %% [markdown]
# # cleansing

# %% [markdown]
# #### Column date

# %%
data_all_df.columns
# Out:
# Index(['date', 'away', 'home', 'first_downs_away', 'first_downs_home',
#        'third_downs_away', 'third_downs_home', 'fourth_downs_away',
#        'fourth_downs_home', 'passing_yards_away', 'passing_yards_home',
#        'rushing_yards_away', 'rushing_yards_home', 'total_yards_away',
#        'total_yards_home', 'comp_att_away', 'comp_att_home', 'sacks_away',
#        'sacks_home', 'rushing_attempts_away', 'rushing_attempts_home',
#        'fumbles_away', 'fumbles_home', 'int_away', 'int_home',
#        'turnovers_away', 'turnovers_home', 'penalties_away', 'penalties_home',
#        'redzone_away', 'redzone_home', 'drives_away', 'drives_home',
#        'def_st_td_away', 'def_st_td_home', 'possession_away',
#        'possession_home', 'score_away', 'score_home'],
#       dtype='object')

# %%
data_all_df['date'].nunique()
# Out:
# 973

# %%
data_all_df['date'].unique()

#looks good, no cleansing needed
# Out:
# array(['9/5/2002', '9/8/2002', '9/9/2002', '9/15/2002', '9/16/2002',
#        '9/22/2002', '9/23/2002', '9/29/2002', '9/30/2002', '10/6/2002',
#        '10/7/2002', '10/13/2002', '10/14/2002', '10/20/2002',
#        '10/21/2002', '10/27/2002', '10/28/2002', '11/3/2002', '11/4/2002',
#        '11/10/2002', '11/11/2002', '11/17/2002', '11/18/2002',
#        '11/24/2002', '11/25/2002', '11/28/2002', '12/1/2002', '12/2/2002',
#        '12/8/2002', '12/9/2002', '12/15/2002', '12/16/2002', '12/21/2002',
#        '12/22/2002', '12/23/2002', '12/28/2002', '12/29/2002',
#        '12/30/2002', '1/2/2005', '1/8/2005', '1/9/2005', '1/15/2005',
#        '1/16/2005', '1/23/2005', '2/6/2005', '9/8/2005', '9/11/2005',
#        '9/12/2005', '9/18/2005', '9/19/2005', '9/25/2005', '9/26/2005',
#        '10/2/2005', '10/3/2005', '10/9/2005', '10/10/2005', '10/16/2005',
#        '10/17/2005', '10/21/2005', '10/23/2005', '10/24/2005',
# ...

# %% [markdown]
# #### Column away & home

# %%
data_all_df['away'].unique()
# have to clean the space and dot in teams' name
# Out:
# array(['  .  49ers', 'Seahawks', 'Jets', 'Vikings', 'Chargers', 'Chiefs',
#        'Falcons', 'Eagles', 'Lions', 'Cardinals', 'Ravens', 'Colts',
#        'Rams', 'Saints', 'Cowboys', 'Steelers', '  .  Bears', 'Packers',
#        'Bengals', 'Titans', 'Dolphins', 'Jaguars', 'Patriots',
#        'Buccaneers', 'Giants', 'Bills', 'Texans', 'Broncos', 'Raiders',
#        '  .  Jets', 'Browns', 'Panthers', 'Washington', '  .  Browns',
#        'Bears', '  .  Jaguars', '49ers', '  .  Seahawks', '  .  Titans',
#        '  .  Lions', '  .  Texans', '  .  Rams', '  .  Dolphins',
#        '  .  Panthers', '  .  Packers', '  .  Bills', '  .  Buccaneers',
#        '  .  Steelers', '  .  Cowboys', '  .  Broncos', '  .  Eagles',
#        '  .  Giants', '  .  Falcons', '  .  Chiefs', '  .  Washington',
#        '  .  Raiders', '  .  Ravens', '  .  Bengals', '  .  Chargers',
#        '  .  Patriots', '  .  Cardinals', '  .  Colts', '  .  Vikings'],
#       dtype=object)

# %%
data_all_df['away'].nunique()
# Out:
# 63

# %%
data_all_df['away'].dtype
# Out:
# dtype('O')

# %%
data_all_df.away=data_all_df.away.str.replace('.','').str.lstrip()
# remove all the white space and dot in Teams'name
# Out:
# <ipython-input-35-9ad183e0a89e>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data_all_df.away=data_all_df.away.str.replace('.','').str.lstrip()

# %%
data_all_df['away'].unique()
# Out:
# array(['49ers', 'Seahawks', 'Jets', 'Vikings', 'Chargers', 'Chiefs',
#        'Falcons', 'Eagles', 'Lions', 'Cardinals', 'Ravens', 'Colts',
#        'Rams', 'Saints', 'Cowboys', 'Steelers', 'Bears', 'Packers',
#        'Bengals', 'Titans', 'Dolphins', 'Jaguars', 'Patriots',
#        'Buccaneers', 'Giants', 'Bills', 'Texans', 'Broncos', 'Raiders',
#        'Browns', 'Panthers', 'Washington'], dtype=object)

# %%
data_all_df['away'].nunique()
# Out:
# 32

# %%
data_all_df.home.unique()
# Out:
# array(['Giants', 'Raiders', 'Bills', 'Bears', 'Bengals', 'Browns',
#        'Packers', 'Titans', 'Dolphins', 'Washington', 'Panthers',
#        'Jaguars', 'Broncos', 'Buccaneers', 'Texans', 'Patriots',
#        'Falcons', 'Saints', 'Cowboys', 'Colts', 'Chiefs', 'Jets',
#        'Ravens', 'Rams', 'Seahawks', 'Vikings', 'Chargers', '49ers',
#        'Steelers', 'Eagles', 'Cardinals', 'Lions'], dtype=object)

# %%
data_all_df.home.nunique()
# nothing to clean for column home
# Out:
# 32

# %%
data_all_df.home.unique()
# Out:
# array(['Giants', 'Raiders', 'Bills', 'Bears', 'Bengals', 'Browns',
#        'Packers', 'Titans', 'Dolphins', 'Washington', 'Panthers',
#        'Jaguars', 'Broncos', 'Buccaneers', 'Texans', 'Patriots',
#        'Falcons', 'Saints', 'Cowboys', 'Colts', 'Chiefs', 'Jets',
#        'Ravens', 'Rams', 'Seahawks', 'Vikings', 'Chargers', '49ers',
#        'Steelers', 'Eagles', 'Cardinals', 'Lions'], dtype=object)

# %%
data_all_df.away.isin(data_all_df.home).unique()
# "away" Teams'names match "home" Teams'names
# Out:
# array([ True])

# %% [markdown]
# #### Column total_yards_away

# %%
data_all_df.total_yards_away.unique()
# Out:
# array([279, 423, 266, 368, 401, 470, 374, 261, 257, 289, 307, 327, 267,
#        283, 242, 357, 333, 342, 450, 432, 122, 394, 347, 468, 118, 299,
#        464, 451, 189, 302, 403, 370, 349, 304, 339, 291, 442, 145, 217,
#        191, 358, 245, 240, 332, 399, 315, 345, 363, 263, 430, 440, 443,
#        495, 316, 410, 364, 312, 314, 504, 313, 406, 409, 457, 198, 408,
#        308, 244, 354, 301, 194, 311, 367, 319, 259, 351, 290, 205, 224,
#        507, 294, 418, 389, 397, 238, 207, 282, 417, 218, 446, 334, 226,
#        420, 258, 348, 340, 422, 309, 391, 221, 387, 390, 413, 434, 415,
#        329, 306, 362, 233, 256, 460, 447, 372, 344, 382, 178, 166, 248,
#        321, 467, 231, 157, 195, 220, 552, 326, 144, 352, 426, 402, 520,
#        369, 343, 250, 477, 300, 247, 234, 379, 476, 165, 274, 328, 202,
#         47, 181, 203, 359, 393, 376, 439, 292, 131, 298, 494, 241, 378,
#        176, 239, 208, 210, 185, 469, 383, 186, 271, 324, 209, 273, 317,
# ...

# %%
data_all_df['total_yards_away'].isna().sum()
# Out:
# 0
